# %%
import pandas as pd
from keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\Users\shash\.conda\envs\flaskenv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
sentences = [
    'The Glass of Milk',
    'The Glass of Water',
    'the Cup of Tea',
    'I am Software Engineer',
    'Your Videos Are Good'
]

# %%
voc_words =10000
onehot = [one_hot(word,voc_words) for word in sentences]
onehot
# Out:
# [[2162, 7650, 975, 2225],
#  [2162, 7650, 975, 7011],
#  [2162, 670, 975, 5256],
#  [6961, 7908, 5039, 4182],
#  [3189, 6558, 1373, 4125]]

# %%
from keras.models import Sequential
from keras.utils import pad_sequences
from keras.layers import Embedding

# %%
sent_length = 8
word_len = pad_sequences(onehot , maxlen=sent_length,padding='pre')
word_len
# Out:
# array([[   0,    0,    0,    0, 2162, 7650,  975, 2225],
#        [   0,    0,    0,    0, 2162, 7650,  975, 7011],
#        [   0,    0,    0,    0, 2162,  670,  975, 5256],
#        [   0,    0,    0,    0, 6961, 7908, 5039, 4182],
#        [   0,    0,    0,    0, 3189, 6558, 1373, 4125]])

# %%
dim = 10

model = Sequential()
model.add(Embedding(voc_words,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From c:\Users\shash\.conda\envs\flaskenv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\shash\.conda\envs\flaskenv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(word_len)
# Out:
# 1/1 [==============================] - 0s 210ms/step
# array([[[-4.30274755e-04,  3.17162611e-02,  3.09900902e-02,
#          -3.23744863e-03,  2.76947133e-02,  3.30003165e-02,
#           2.74438895e-02,  4.42775004e-02,  4.64076139e-02,
#           1.90260150e-02],
#         [-4.30274755e-04,  3.17162611e-02,  3.09900902e-02,
#          -3.23744863e-03,  2.76947133e-02,  3.30003165e-02,
#           2.74438895e-02,  4.42775004e-02,  4.64076139e-02,
#           1.90260150e-02],
#         [-4.30274755e-04,  3.17162611e-02,  3.09900902e-02,
#          -3.23744863e-03,  2.76947133e-02,  3.30003165e-02,
#           2.74438895e-02,  4.42775004e-02,  4.64076139e-02,
#           1.90260150e-02],
#         [-4.30274755e-04,  3.17162611e-02,  3.09900902e-02,
#          -3.23744863e-03,  2.76947133e-02,  3.30003165e-02,
#           2.74438895e-02,  4.42775004e-02,  4.64076139e-02,
#           1.90260150e-02],
#         [-2.62385961e-02,  2.43351720e-02,  2.27580704e-02,
#          -1.64661631e-02, -1.39517672e-02,  4.42060120e-02,
#           2.68445723e-02, -1.80672854e-04, -4.37107347e-02,
#           4.42739241e-02],
#         [-1.98842529e-02,  4.93090227e-03, -1.61945820e-03,
#           2.87864842e-02,  4.92962264e-02,  2.55770423e-02,
#          -3.09961084e-02,  7.89435953e-03, -1.28250122e-02,
#           6.14941120e-04],
#         [ 5.80730289e-03,  2.39151977e-02, -8.67024064e-05,
#          -4.31325100e-02,  7.01043755e-03,  4.30779122e-02,
#          -3.30327153e-02, -1.24816522e-02, -1.43038407e-02,
#          -8.68344307e-03],
#         [ 2.76407935e-02, -2.17091199e-02, -2.66657602e-02,
#           6.83969259e-03,  9.96534899e-03, -3.81168947e-02,
#          -5.66235930e-03, -4.01817672e-02, -4.30397764e-02,
#          -7.14535639e-03]],
#
#        [[-4.30274755e-04,  3.17162611e-02,  3.09900902e-02,
#          -3.23744863e-03,  2.76947133e-02,  3.30003165e-02,
#           2.74438895e-02,  4.42775004e-02,  4.64076139e-02,
#           1.90260150e-02],
#         [-4.30274755e-04,  3.17162611e-02,  3.09900902e-02,
#          -3.23744863e-03,  2.76947133e-02,  3.30003165e-02,
#           2.74438895e-02,  4.42775004e-02,  4.64076139e-02,
#           1.90260150e-02],
#         [-4.30274755e-04,  3.17162611e-02,  3.09900902e-02,
#          -3.23744863e-03,  2.76947133e-02,  3.30003165e-02,
#           2.74438895e-02,  4.42775004e-02,  4.64076139e-02,
#           1.90260150e-02],
#         [-4.30274755e-04,  3.17162611e-02,  3.09900902e-02,
#          -3.23744863e-03,  2.76947133e-02,  3.30003165e-02,
#           2.74438895e-02,  4.42775004e-02,  4.64076139e-02,
#           1.90260150e-02],
#         [-2.62385961e-02,  2.43351720e-02,  2.27580704e-02,
#          -1.64661631e-02, -1.39517672e-02,  4.42060120e-02,
#           2.68445723e-02, -1.80672854e-04, -4.37107347e-02,
#           4.42739241e-02],
#         [-1.98842529e-02,  4.93090227e-03, -1.61945820e-03,
#           2.87864842e-02,  4.92962264e-02,  2.55770423e-02,
#          -3.09961084e-02,  7.89435953e-03, -1.28250122e-02,
#           6.14941120e-04],
#         [ 5.80730289e-03,  2.39151977e-02, -8.67024064e-05,
